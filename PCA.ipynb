# %%
from sklearn.decomposition import PCA # make an instance of the model

pca = PCA(n_components=2)
pca.fit(x_train) # we only fit pca on data training
data = pca.transform(x)

# %%
dimensional reduction

contoh:
cantik

variabelnya hidung, warna kulit, bentuk muka, bentuk mata, gerak tubuh, suara, tinggi, berat, pinter, talented
variabelnya hanya cantik atau tidak, jadi hanya 1 variabel

otak
spongebob

merubah koordinat x,y di cartesius
bisa di pindahkan pusatnya (coordinat 0,0)
bisa diputar koordinatnya (best fitting line)







WHAT PCA DOES?
HOW IT DOES IT?
HOW TO USE IT TO GET DEEPER INSIDE INTO YOUR DATA?

SAMPLE -> TIKUS
VARIABEL -> GENE 1, GENE 2

SAMPLE -> STUDENT
VARIABEL -> MATH, READING

SAMPLE -> BUSINESS
VARIABEL -> MARKET CAP, # EMPLOYEE

            SAMPLE/OBJECT 1     SAMPLE/OBJECT 2     SAMPLE/OBJECT 3      SAMPLE/OBJECT 4
VARIABLE 1
VARIABEL 2


        | Mouse1 mouse2 mouse3 mouse4 mouse5 mouse6
         ---------------------------------------------
gene 1  | 10     11     8      3      2      1


    6     5    4                  3           1    2
  ----------------------------------------------------
Low value                                      High value
                        gene 1

    
    
        | Mouse1 mouse2 mouse3 mouse4 mouse5 mouse6
         ---------------------------------------------
gene 1  | 10     11     8      3      2      1
gene 2  | 6      4      5      3      2.8    1

gene 2
|
|
|
|
|
|                               1
|                         3
|                                 2
|
|          4
|  5
|    
|       6
|
--------------------------------------------- gene 1




        | Mouse1 mouse2 mouse3 mouse4 mouse5 mouse6
         ---------------------------------------------
gene 1  | 10     11     8      3      2      1
gene 2  | 6      4      5      3      2.8    1
gene 3  | 

sama kaya kedua tapi ukuran





        | Mouse1 mouse2 mouse3 mouse4 mouse5 mouse6
         ---------------------------------------------
gene 1  | 10     11     8      3      2      1
gene 2  | 6      4      5      3      2.8    1
gene 3  | 
gene 4  |
    

merubah koordinat x,y di cartesius
bisa di pindahkan pusatnya (coordinat 0,0)
bisa diputar koordinatnya (best fitting line)
  (unit vector that we just calculate)

lalu di reduction deimensionality d1 d2 d3 d4 d5 d6 = sum of square distances = SS(distaces)
rumus cubic area

slope 0.25
(x,y)
(4,1)

to make PC1
mix 4 parts gene 1
with 1 part gene 2

it proves that gene 1 is more important than gene 2 (often, because we move the (0,0) coordinate into the new point)

then pythagoras:
    a=4 b=1 c=4.12
scaling:
    a=4/4.12=0.97 b=1/4.12=0.242 c=4.12/4.12=1

to make PC1
mix 0.97 parts gene 1
with 0.242 part gene 2
    
the data
(best fitting line)
(unit vector that we just calculate)
    
the vector, 
garis lurus yg baru namanya 
this one unit long vector ,
consisting of 0.97 parts gene 1 and 0.242 parts of gene 2, 
is called the "Singular vector" or the "Eigenvector" for PC1

and proportions of each genes is called "loading scores"
    
SS(Distances) = Eigenvalue for PC1
sqrt(Eigenvalue for PC1) = Singular Value for PC1
    
    
    

90' from PC1

Loading Scores for PC2

-0.242 parts Gene 1
0.97 parts Gene 2

SS(Distances) = Eigenvalue for PC2
sqrt(Eigenvalue for PC2) = Singular Value for PC2

  
    
    
rotate PC1 horizontal
that's how PCA is done using Singular Value Decomposition (SVD)

SS(Distances for PC1)/n-1 = Variation for PC1
SS(Distances for PC2)/n-1 = Variation for PC2
variation PC1 = 15
variation PC2 = 3
total variation = 18

(15/18)*100 = 83%
100% - 83% = 17%


*
      *
            *
                  *
PC1   PC2   PC3   PC4

note: if the scree plot looked like this,
    where PC3 and PC4 account for a substantial amount of variation,
    then just using the first 2 PCs would not create a very accurate representation of the data.
    
what should be:

*
    
    
    

      *
            *
                  *
PC1   PC2   PC3   PC4

"karena tujuannya me reduksi."
jadi nilainya harus berubah jauh 
selisih antara PC1 dan PC2 sangat jauh
dan selisih PC2 dan PC3 dekat 

    
jadi, menjelaskan kalau Eigenvalue semakin kecil ketika PC semakin besar
Eigenvalue  SEMAKIN KECIL 4.XX 0.9XX 0.8XX
PC          SEMAKIN BESAR PC1 PC2 PC3 PC4
