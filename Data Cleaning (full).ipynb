# %% [markdown]
# ## Import Library

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
plt.style.use('fivethirtyeight')
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Import Data (DataFrame CSV, JSON, XLS)

# %%
df = pd.read_csv(r'C:\Users\LENOVO\Documents\jupyter\visualisasi\dataset\Automobile_data.csv')
df.head(10)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
# 5          2                 ?         audi       gas        std          two
# 6          1               158         audi       gas        std         four
# 7          1                 ?         audi       gas        std         four
# 8          1               158         audi       gas      turbo         four
# 9          0                 ?         audi       gas      turbo          two
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
df_final=df_final.sort_values(by="Tanggal")
df_final['Harga'] = df_final['Harga'].astype('int64', copy=False)
df_final['Tanggal'] = pd.to_datetime(df_final['Tanggal'], format='%d/%m/%Y')
df_copy=df.drop(df.columns[[0]], axis=1)
item = df_copy.columns
df_final = pd.DataFrame(columns=['Komoditas','Harga','Tanggal'])
for item in df_copy:
    komo=df[['Komoditas(Rp)', item]]
    komo.rename(columns={item:'Harga'}, inplace=True)
    komo['Tanggal']=item
    komo.rename(columns={'Komoditas(Rp)':'Komoditas'}, inplace=True)
    df_final=df_final.append(komo)
    
df = df.drop(['C', 'D'], axis=1)
melb_cheap     = melb_data[melb_data['Price']  <= melb_data['Price'].describe()['25%']]

# %% [markdown]
# # Data Cleaning
#
# 1. Wrong format data
# 2. Duplicate data
# 3. Null/NaN data
# 4. Outlier

# %% [markdown]
# ### 1. Wrong format data

# %%
# cek data typesnya, biasanya yg harusnya numeric tapi malah object yg salah
df.dtypes

# dicoba ganti format ke numeric, biar kelitan kalau ada ERROR. kalau bisa artinya ga ada ERROR. kalau ERROR dikasih tau sama pythonnya.
normalized_losses_numeric = pd.to_numeric(df['normalized-losses'])

# untuk melihat unique value nya ada berapa, apakah wajar
df['fuel-type'].unique()
df.nunique()

# kalau mau replace value dengan null/NaN
df['normalized-losses'].replace('?',np.NaN)

# kalau mau merubah value
df_final['Komoditas'] = df_final['Komoditas'].str.replace('kg','').str.replace('(','').str.replace(')','')
df_final['Komoditas'] = df_final['Komoditas'].str.strip()

https://docs.python.org/3/library/string.html

# %% [markdown]
# ### 2. Duplicate Data

# %%
# ngecek ada atau engga
print(np.where(df.duplicated() == True))

# kalau ada, dicek di baris ke berapa
print(df.duplicated().iloc[516:536])

# dicek secara mendetail, duplicate valuenya gimana
df.iloc[494]

# dari valuenya, dicek samanya gimana (itu perlu dihapus atau engga)
np.where(df['Description'] == 'UNION JACK FLAG LUGGAGE TAG')
# Out:
# (array([], dtype=int64),)

# %% [markdown]
# ### 3. Null/NaN Data

# %%
# ngecek apakah ada null/NaN value
df.isnull().values.any()

# ngeliat semua null data dalam format boolean
df.isnull()

# ngeluat berapa jumlah record yg berniai true dari DataFrame diatas
df.isnull().sum()

# di ilangin baris datanya atau
df.dropna()

# diisi dengan mean/median/mode
df.describe()
df.fillna(df['description'].mean())

# %% [markdown]
# ### 4. Outlier

# %%
# Cara 1
#import scipy.stats
import scipy.stats as stats

#set the resource list and the condition for outlier
list_df = df['Apps']
z_scores = stats.zscore(list_df) 
abs_z_scores = np.abs(z_scores)
filtered_entries = (abs_z_scores > 3)

df_Apps = list_df[filtered_entries]
print(df_Apps)

# kalau mau dibuang outliernya
df = df[filtered_entries]

#Visualize
fig = plt.figure()
ax = plt.axes()

ax.bar(df['Unnamed: 0'], df['Apps'])

ax.set_title('Application to College 1995')
ax.set_xlabel('Name of College')
ax.set_ylabel('Sum of Applications')

plt.show()

# to see detailly
df.iloc[483]






# Cara 2
# tentukan batas_atas dan batas_bawah
Q1 = list_TotalCost.quantile(.25)
Q2 = list_TotalCost.quantile(.50)
Q3 = list_TotalCost.quantile(.75)

IQR = (Q3 - Q1) * 1.5
batas_bawah= Q1-IQR
batas_atas = Q3+IQR

# buat fungsi untuk outlier
def find_outlier(yourlist):
    outlier = []
    for i in range(len(yourlist)):
        if yourlist[i] > batas_atas:
            outlier.append(yourlist[i])
        if yourlist[i] < batas_bawah:
            outlier.append(yourlist[i])
        
    return outlier

# ambil data dan menjalankan fungsi
list_TotalCost = df['TotalCost']
find_outlier(list_TotalCost)

# cek secara mendetail data outlier nya
df[df['TotalCost']  >= batas_atas]
print(df['TotalCost'].iloc[9])

df[df['TotalCost']  >= batas_bawah]
print(df['TotalCost'].iloc[])

# untuk menghilangkan yg melewati batas_atas
df.shape()
df = df[df['TotalCost']  <= batas_atas]
df
df.shape()

# untuk menghilangkan yg melebihi batas bawah
df.shape()
df = df[df['TotalCost']  >= batas_bawah]
df
df.shape()
